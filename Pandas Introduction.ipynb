# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Series

# %%
mydata = ['Boat', 'Car', 'Bike', 'Truck']
myseries1 = pd.Series(mydata)

# %%
print(myseries1)
# Out:
# 0     Boat
# 1      Car
# 2     Bike
# 3    Truck
# dtype: object

# %%
mydata = [1,55,99,43]
myseries2 = pd.Series(mydata)
print(myseries2)
# Out:
# 0     1
# 1    55
# 2    99
# 3    43
# dtype: int64

# %% [markdown]
# # DataFrame

# %%
mydfdata = [('Boat',1), ('Car',55), ('Bike', 99), ('Truck', 43)]
mydf = pd.DataFrame(mydfdata, columns=['thing', 'count'])
mydf
# Out:
#    thing  count
# 0   Boat      1
# 1    Car     55
# 2   Bike     99
# 3  Truck     43

# %%
mydf.dtypes
# Out:
# thing    object
# count     int64
# dtype: object

# %% [markdown]
# # Reading in Data

# %%
df = pd.read_csv('/Users/ngating/Desktop/Data engineer project/Electric_Vehicle_Population_Data.csv')

# %% [markdown]
# # Inspect The Data

# %%
df.head()
# Out:
#    VIN (1-10)     County       City State  Postal Code  Model Year   Make  \
# 0  5YJYGDEE1L       King    Seattle    WA      98122.0        2020  TESLA
# 1  7SAYGDEE9P  Snohomish    Bothell    WA      98021.0        2023  TESLA
# 2  5YJSA1E4XK       King    Seattle    WA      98109.0        2019  TESLA
# 3  5YJSA1E27G       King   Issaquah    WA      98027.0        2016  TESLA
# 4  5YJYGDEE5M     Kitsap  Suquamish    WA      98392.0        2021  TESLA
#
#      Model           Electric Vehicle Type  \
# 0  MODEL Y  Battery Electric Vehicle (BEV)
# 1  MODEL Y  Battery Electric Vehicle (BEV)
# 2  MODEL S  Battery Electric Vehicle (BEV)
# 3  MODEL S  Battery Electric Vehicle (BEV)
# 4  MODEL Y  Battery Electric Vehicle (BEV)
#
#    Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0            Clean Alternative Fuel Vehicle Eligible             291
# 1  Eligibility unknown as battery range has not b...               0
# ...

# %%
df.tail()
# Out:
#         VIN (1-10)  County           City State  Postal Code  Model Year  \
# 177861  7SAYGDEE3N  Pierce    Bonney Lake    WA      98391.0        2022
# 177862  KM8K23AG1P   Mason        Shelton    WA      98584.0        2023
# 177863  5YJYGDEE6M   Grant         Quincy    WA      98848.0        2021
# 177864  WVGKMPE27M    King  Black Diamond    WA      98010.0        2021
# 177865  5YJ3E1EA8M  Pierce         Tacoma    WA      98422.0        2021
#
#               Make          Model           Electric Vehicle Type  \
# 177861       TESLA        MODEL Y  Battery Electric Vehicle (BEV)
# 177862     HYUNDAI  KONA ELECTRIC  Battery Electric Vehicle (BEV)
# 177863       TESLA        MODEL Y  Battery Electric Vehicle (BEV)
# 177864  VOLKSWAGEN           ID.4  Battery Electric Vehicle (BEV)
# 177865       TESLA        MODEL 3  Battery Electric Vehicle (BEV)
#
#         Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# ...

# %%
df.dtypes
# Out:
# VIN (1-10)                                            object
# County                                                object
# City                                                  object
# State                                                 object
# Postal Code                                          float64
# Model Year                                             int64
# Make                                                  object
# Model                                                 object
# Electric Vehicle Type                                 object
# Clean Alternative Fuel Vehicle (CAFV) Eligibility     object
# Electric Range                                         int64
# Base MSRP                                              int64
# Legislative District                                 float64
# DOL Vehicle ID                                         int64
# Vehicle Location                                      object
# ...

# %%
df.describe() #it only works on numeric column
# Out:
#          Postal Code     Model Year  Electric Range      Base MSRP  \
# count  177861.000000  177866.000000   177866.000000  177866.000000
# mean    98172.453506    2020.515512       58.842162    1073.109363
# std      2442.450668       2.989384       91.981298    8358.624956
# min      1545.000000    1997.000000        0.000000       0.000000
# 25%     98052.000000    2019.000000        0.000000       0.000000
# 50%     98122.000000    2022.000000        0.000000       0.000000
# 75%     98370.000000    2023.000000       75.000000       0.000000
# max     99577.000000    2024.000000      337.000000  845000.000000
#
#        Legislative District  DOL Vehicle ID  2020 Census Tract
# count         177477.000000    1.778660e+05       1.778610e+05
# mean              29.127481    2.202313e+08       5.297672e+10
# std               14.892169    7.584987e+07       1.578047e+09
# min                1.000000    4.385000e+03       1.001020e+09
# ...

# %% [markdown]
# # Columns and Rows

# %%
df['Electric Range']
# Out:
# 0         291
# 1           0
# 2         270
# 3         210
# 4           0
#          ...
# 177861      0
# 177862      0
# 177863      0
# 177864      0
# 177865      0
# Name: Electric Range, Length: 177866, dtype: int64

# %%
df.loc[4]
# Out:
# VIN (1-10)                                                                                  5YJYGDEE5M
# County                                                                                          Kitsap
# City                                                                                         Suquamish
# State                                                                                               WA
# Postal Code                                                                                    98392.0
# Model Year                                                                                        2021
# Make                                                                                             TESLA
# Model                                                                                          MODEL Y
# Electric Vehicle Type                                                   Battery Electric Vehicle (BEV)
# ...

# %%
#df = df.set_index('VIN (1-10) ') 
#setting an index should be a unique value. But there is a missing value in column 6122, so there is an error

# %% [markdown]
# # Subsetting data

# %%
df.columns
# Out:
# Index(['VIN (1-10)', 'County', 'City', 'State', 'Postal Code', 'Model Year',
#        'Make', 'Model', 'Electric Vehicle Type',
#        'Clean Alternative Fuel Vehicle (CAFV) Eligibility', 'Electric Range',
#        'Base MSRP', 'Legislative District', 'DOL Vehicle ID',
#        'Vehicle Location', 'Electric Utility', '2020 Census Tract'],
#       dtype='object')

# %%
#Subsetting Columns
df = df[['Model Year', 'Make', 'Model', 'Electric Vehicle Type',
       'Clean Alternative Fuel Vehicle (CAFV) Eligibility', 'Electric Range',
       'Base MSRP', 'Legislative District', 'DOL Vehicle ID',
       'Vehicle Location', 'Electric Utility']]

# %%
df.shape
# Out:
# (177866, 11)

# %%
#Subsetting Rows
df['Electric Range'] >50
# Out:
# 0          True
# 1         False
# 2          True
# 3          True
# 4         False
#           ...
# 177861    False
# 177862    False
# 177863    False
# 177864    False
# 177865    False
# Name: Electric Range, Length: 177866, dtype: bool

# %%
#Subsetting Rows Using loc
df.loc[df['Electric Range'] >50]
# Out:
#         Model Year       Make    Model           Electric Vehicle Type  \
# 0             2020      TESLA  MODEL Y  Battery Electric Vehicle (BEV)
# 2             2019      TESLA  MODEL S  Battery Electric Vehicle (BEV)
# 3             2016      TESLA  MODEL S  Battery Electric Vehicle (BEV)
# 6             2013     NISSAN     LEAF  Battery Electric Vehicle (BEV)
# 8             2015     NISSAN     LEAF  Battery Electric Vehicle (BEV)
# ...            ...        ...      ...                             ...
# 177852        2018      TESLA  MODEL 3  Battery Electric Vehicle (BEV)
# 177854        2019      TESLA  MODEL 3  Battery Electric Vehicle (BEV)
# 177855        2018      TESLA  MODEL 3  Battery Electric Vehicle (BEV)
# 177857        2015     NISSAN     LEAF  Battery Electric Vehicle (BEV)
# 177860        2018  CHEVROLET  BOLT EV  Battery Electric Vehicle (BEV)
#
#        Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# ...

# %%
df_subset1 = df.loc[df['Electric Range'] > 50]

# %%
df.query('`Electric Range` > 50')
#because there is a space bewteen Electric Range, a quote should be added to include Electric Range
# Out:
#         Model Year       Make    Model           Electric Vehicle Type  \
# 0             2020      TESLA  MODEL Y  Battery Electric Vehicle (BEV)
# 2             2019      TESLA  MODEL S  Battery Electric Vehicle (BEV)
# 3             2016      TESLA  MODEL S  Battery Electric Vehicle (BEV)
# 6             2013     NISSAN     LEAF  Battery Electric Vehicle (BEV)
# 8             2015     NISSAN     LEAF  Battery Electric Vehicle (BEV)
# ...            ...        ...      ...                             ...
# 177852        2018      TESLA  MODEL 3  Battery Electric Vehicle (BEV)
# 177854        2019      TESLA  MODEL 3  Battery Electric Vehicle (BEV)
# 177855        2018      TESLA  MODEL 3  Battery Electric Vehicle (BEV)
# 177857        2015     NISSAN     LEAF  Battery Electric Vehicle (BEV)
# 177860        2018  CHEVROLET  BOLT EV  Battery Electric Vehicle (BEV)
#
#        Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# ...

# %%
df_subset2 = df.query('`Electric Range` > 50')

# %%
df['Electric Range'].isna()
#isna means is there any missing value in the dataset, 
#False means no missing value and true means there is missing value
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 177861    False
# 177862    False
# 177863    False
# 177864    False
# 177865    False
# Name: Electric Range, Length: 177866, dtype: bool

# %%
df.loc[df['Electric Range'].isna()]
#there is no misssing value, so no value can be printed
# Out:
# Empty DataFrame
# Columns: [Model Year, Make, Model, Electric Vehicle Type, Clean Alternative Fuel Vehicle (CAFV) Eligibility, Electric Range, Base MSRP, Legislative District, DOL Vehicle ID, Vehicle Location, Electric Utility]
# Index: []

# %%
df.loc[~df['Electric Range'].isna()]
#~means opposite, all value are present
# Out:
#         Model Year        Make          Model           Electric Vehicle Type  \
# 0             2020       TESLA        MODEL Y  Battery Electric Vehicle (BEV)
# 1             2023       TESLA        MODEL Y  Battery Electric Vehicle (BEV)
# 2             2019       TESLA        MODEL S  Battery Electric Vehicle (BEV)
# 3             2016       TESLA        MODEL S  Battery Electric Vehicle (BEV)
# 4             2021       TESLA        MODEL Y  Battery Electric Vehicle (BEV)
# ...            ...         ...            ...                             ...
# 177861        2022       TESLA        MODEL Y  Battery Electric Vehicle (BEV)
# 177862        2023     HYUNDAI  KONA ELECTRIC  Battery Electric Vehicle (BEV)
# 177863        2021       TESLA        MODEL Y  Battery Electric Vehicle (BEV)
# 177864        2021  VOLKSWAGEN           ID.4  Battery Electric Vehicle (BEV)
# 177865        2021       TESLA        MODEL 3  Battery Electric Vehicle (BEV)
#
# ...

# %% [markdown]
# # Casting Dtypes

# %%
df.dtypes
# Out:
# Model Year                                             int64
# Make                                                  object
# Model                                                 object
# Electric Vehicle Type                                 object
# Clean Alternative Fuel Vehicle (CAFV) Eligibility     object
# Electric Range                                         int64
# Base MSRP                                              int64
# Legislative District                                 float64
# DOL Vehicle ID                                         int64
# Vehicle Location                                      object
# Electric Utility                                      object
# dtype: object

# %%
df['Electric Range'].astype('int')
#actually it is used to change the datatype, 
#but there is no missing value in electric range, and the datatype is correct
#so this is for record only
#if there is missing value and it is being removed, 
#the datatype can be changed from float64 to int64
# Out:
# 0         291
# 1           0
# 2         270
# 3         210
# 4           0
#          ...
# 177861      0
# 177862      0
# 177863      0
# 177864      0
# 177865      0
# Name: Electric Range, Length: 177866, dtype: int64

# %%
#df['publishTime'] = pd.to_datetime(df['publishTime'])
#If there is datetime variable, we can convert it into datetime data type as above
#publishTime is the variable in the dataset

# %%
df['Electric Range'] = pd.to_numeric(df['Electric Range'].astype('str'))
#it can either be in numeric datatype or string datatype (if there is null value)

# %% [markdown]
# # Creating new column

# %%
df['Electric_Range_max100'] = df['Electric Range']/10

# %%
df.head()
# Out:
#    Model Year   Make    Model           Electric Vehicle Type  \
# 0        2020  TESLA  MODEL Y  Battery Electric Vehicle (BEV)
# 1        2023  TESLA  MODEL Y  Battery Electric Vehicle (BEV)
# 2        2019  TESLA  MODEL S  Battery Electric Vehicle (BEV)
# 3        2016  TESLA  MODEL S  Battery Electric Vehicle (BEV)
# 4        2021  TESLA  MODEL Y  Battery Electric Vehicle (BEV)
#
#    Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0            Clean Alternative Fuel Vehicle Eligible             291
# 1  Eligibility unknown as battery range has not b...               0
# 2            Clean Alternative Fuel Vehicle Eligible             270
# 3            Clean Alternative Fuel Vehicle Eligible             210
# 4  Eligibility unknown as battery range has not b...               0
#
#    Base MSRP  Legislative District  DOL Vehicle ID  \
# 0          0                  37.0       125701579
# 1          0                   1.0       244285107
# ...

# %% [markdown]
# # Adding New Row

# %%
df_to_append = df.tail(1)

# %%
pd.concat([df, df_to_append])
# Out:
#         Model Year        Make          Model           Electric Vehicle Type  \
# 0             2020       TESLA        MODEL Y  Battery Electric Vehicle (BEV)
# 1             2023       TESLA        MODEL Y  Battery Electric Vehicle (BEV)
# 2             2019       TESLA        MODEL S  Battery Electric Vehicle (BEV)
# 3             2016       TESLA        MODEL S  Battery Electric Vehicle (BEV)
# 4             2021       TESLA        MODEL Y  Battery Electric Vehicle (BEV)
# ...            ...         ...            ...                             ...
# 177862        2023     HYUNDAI  KONA ELECTRIC  Battery Electric Vehicle (BEV)
# 177863        2021       TESLA        MODEL Y  Battery Electric Vehicle (BEV)
# 177864        2021  VOLKSWAGEN           ID.4  Battery Electric Vehicle (BEV)
# 177865        2021       TESLA        MODEL 3  Battery Electric Vehicle (BEV)
# 177865        2021       TESLA        MODEL 3  Battery Electric Vehicle (BEV)
#
# ...

# %% [markdown]
# # Plot Examples

# %%
df['Electric Range'].plot(kind='hist', bins=10, 
                          title='The Distribution of the Electric Range among the Electric Vehicle',
                          figsize=(15,5))
# Out:
# <Axes: title={'center': 'The Distribution of the Electric Range among the Electric Vehicle'}, ylabel='Frequency'>

# %%
#df.plot(kind='scatter', x='viewCount', y='likeCount', title= 'View vs like Count')

# %%
df_subset2['Electric Range'].plot(kind='hist', bins=10, 
                          title='The Distribution of the Electric Range among the Electric Vehicle',
                          figsize=(10,10))
# Out:
# <Axes: title={'center': 'The Distribution of the Electric Range among the Electric Vehicle'}, ylabel='Frequency'>

# %% [markdown]
# # Save our output

# %%
df.to_csv('processed_data.csv', index=False)
#If you don't want to save the index column, you can write index=False
